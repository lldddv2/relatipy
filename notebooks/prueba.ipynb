# %%
# pip install https://github.com/lldddv2/kerrpy
# %pip install --upgrade git+https://github.com/lldddv2/relatipy@feature/NUM-KerrMetric-001
# Out:
# ...
#   Cloning https://github.com/lldddv2/relatipy (to revision feature/NUM-KerrMetric-001) to /tmp/pip-req-build-27web70m
#   Running command git clone --filter=blob:none --quiet https://github.com/lldddv2/relatipy /tmp/pip-req-build-27web70m
#   Running command git checkout -b feature/NUM-KerrMetric-001 --track origin/feature/NUM-KerrMetric-001
#   Cambiado a nueva rama 'feature/NUM-KerrMetric-001'
#   rama 'feature/NUM-KerrMetric-001' configurada para rastrear 'origin/feature/NUM-KerrMetric-001'.
#   Resolved https://github.com/lldddv2/relatipy to commit 81665856834f30080469dfeb351cd97d35487e9f
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Note: you may need to restart the kernel to use updated packages.

# %%
import relatipy as rp
